# %%
'''
Range in python :- 
Range always generate the sequence of interger value
Range is predefined function in python which used with the for loop
syntax
range(start,end,step) 
'''
for Num in range(1,11,1):
    print(Num)
